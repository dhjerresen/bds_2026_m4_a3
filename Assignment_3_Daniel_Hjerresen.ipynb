# %% [markdown]
# # Part C

# %%
import json
import requests
import pandas as pd
from typing import TypedDict, Optional
from langgraph.graph import StateGraph, END

CSV_PATH = "hitl_green_100_a3.csv"
OLLAMA_MODEL = "gemma3:4b"
OLLAMA_URL = "http://localhost:11434/api/generate"

SYSTEM = (
    "You are classifying whether a patent claim is GREEN technology. "
    "Use ONLY the claim text. Do NOT use CPC codes or metadata. "
    "Green means explicit climate/energy/environmental benefit: emissions reduction, "
    "renewables, energy efficiency, batteries/EV powertrain, carbon capture, waste/recycling, "
    "water treatment, climate adaptation, etc. General 'efficiency' without environmental purpose is NOT enough."
)

def ollama(prompt: str, num_predict=240) -> str:
    payload = {
        "model": OLLAMA_MODEL,
        "prompt": prompt,
        "stream": False,
        "options": {"temperature": 0.0, "num_predict": num_predict},
    }
    r = requests.post(OLLAMA_URL, json=payload, timeout=180)
    r.raise_for_status()
    return r.json()["response"].strip()

def extract_json(s: str) -> dict:
    s = s.strip()
    if s.startswith("{") and s.endswith("}"):
        return json.loads(s)
    a, b = s.find("{"), s.rfind("}")
    if a != -1 and b != -1 and b > a:
        return json.loads(s[a:b+1])
    raise ValueError("Could not parse JSON:\n" + s[:500])

class DebateState(TypedDict):
    doc_id: int
    text: str
    advocate: Optional[str]
    skeptic: Optional[str]
    judge_json: Optional[dict]

def advocate_node(state: DebateState) -> DebateState:
    prompt = f"""{SYSTEM}

Role: Advocate (argue FOR green).
Given the claim text, argue why it could qualify as green tech. Cite exact phrases.
Return 3-6 bullet points. If no evidence, say: "No strong green evidence found."

Claim:
\"\"\"{state['text']}\"\"\"
"""
    state["advocate"] = ollama(prompt)
    return state

def skeptic_node(state: DebateState) -> DebateState:
    prompt = f"""{SYSTEM}

Role: Skeptic (argue AGAINST green / detect greenwashing).
Argue why it should NOT qualify as green tech. Cite exact phrases.
Return 3-6 bullet points.

Claim:
\"\"\"{state['text']}\"\"\"
"""
    state["skeptic"] = ollama(prompt)
    return state

def judge_node(state: DebateState) -> DebateState:
    prompt = f"""{SYSTEM}

Role: Judge.
Weigh the arguments and decide using ONLY the claim text.

Return ONLY valid JSON with keys:
- agent_judge_suggested: 0 or 1
- agent_judge_confidence: "low" | "medium" | "high"
- agent_judge_rationale: 1-3 sentences citing exact claim phrases

Claim:
\"\"\"{state['text']}\"\"\"

Advocate:
{state['advocate']}

Skeptic:
{state['skeptic']}
"""
    raw = ollama(prompt)
    state["judge_json"] = extract_json(raw)
    return state

def build_graph():
    g = StateGraph(DebateState)
    g.add_node("advocate", advocate_node)
    g.add_node("skeptic", skeptic_node)
    g.add_node("judge", judge_node)

    g.set_entry_point("advocate")
    g.add_edge("advocate", "skeptic")
    g.add_edge("skeptic", "judge")
    g.add_edge("judge", END)
    return g.compile()

def main():
    df = pd.read_csv(CSV_PATH)

    for c in ["agent_advocate", "agent_skeptic", "agent_judge_suggested", "agent_judge_confidence", "agent_judge_rationale"]:
        if c not in df.columns:
            df[c] = ""

    app = build_graph()

    for i in range(len(df)):
        if str(df.at[i, "agent_judge_suggested"]).strip() != "":
            continue

        state: DebateState = {
            "doc_id": int(df.at[i, "doc_id"]),
            "text": str(df.at[i, "text"]),
            "advocate": None,
            "skeptic": None,
            "judge_json": None,
        }

        try:
            out = app.invoke(state)
            df.at[i, "agent_advocate"] = out["advocate"]
            df.at[i, "agent_skeptic"] = out["skeptic"]
            jj = out["judge_json"]
            df.at[i, "agent_judge_suggested"] = int(jj["agent_judge_suggested"])
            df.at[i, "agent_judge_confidence"] = jj["agent_judge_confidence"]
            df.at[i, "agent_judge_rationale"] = jj["agent_judge_rationale"]

            df.to_csv(CSV_PATH, index=False)
            print(f"[{i+1}/{len(df)}] saved")
        except Exception as e:
            print(f"[{i+1}/{len(df)}] error: {e}")

    print("DONE:", CSV_PATH)

if __name__ == "__main__":
    main()
# Out:
# [1/100] saved
# [2/100] saved
# [3/100] saved
# [4/100] saved
# [5/100] saved
# [6/100] saved
# [7/100] saved
# [8/100] saved
# [9/100] saved
# [10/100] saved
# [11/100] saved
# [12/100] saved
# [13/100] saved
# [14/100] saved
# [15/100] saved
# [16/100] saved
# [17/100] saved
# [18/100] saved
# [19/100] saved
# [20/100] saved
# [21/100] saved
# [22/100] saved
# [23/100] saved
# [24/100] saved
# [25/100] saved
# [26/100] saved
# [27/100] saved
# [28/100] saved
# [29/100] saved
# [30/100] saved
# [31/100] saved
# [32/100] saved
# [33/100] saved
# [34/100] saved
# [35/100] saved
# [36/100] saved
# [37/100] saved
# [38/100] saved
# [39/100] saved
# [40/100] saved
# [41/100] saved
# [42/100] saved
# [43/100] saved
# [44/100] saved
# [45/100] saved
# [46/100] saved
# [47/100] saved
# [48/100] saved
# [49/100] saved
# [50/100] saved
# [51/100] saved
# [52/100] saved
# [53/100] saved
# [54/100] saved
# [55/100] saved
# [56/100] saved
# [57/100] saved
# [58/100] saved
# [59/100] saved
# [60/100] saved
# [61/100] saved
# [62/100] saved
# [63/100] saved
# [64/100] saved
# [65/100] saved
# [66/100] saved
# [67/100] saved
# [68/100] saved
# [69/100] saved
# [70/100] saved
# [71/100] saved
# [72/100] saved
# [73/100] saved
# [74/100] saved
# [75/100] saved
# [76/100] saved
# [77/100] saved
# [78/100] saved
# [79/100] saved
# [80/100] saved
# [81/100] saved
# [82/100] saved
# [83/100] saved
# [84/100] saved
# [85/100] saved
# [86/100] saved
# [87/100] saved
# [88/100] saved
# [89/100] saved
# [90/100] saved
# [91/100] saved
# [92/100] saved
# [93/100] saved
# [94/100] saved
# [95/100] saved
# [96/100] saved
# [97/100] saved
# [98/100] saved
# [99/100] saved
# [100/100] saved
# DONE: hitl_green_100_a3.csv

# %% [markdown]
# # Part D

# %%
import pandas as pd

CSV_PATH = "hitl_green_100_a3-hitl.csv"

SHOW_ADV_SKEP = True   # sæt True hvis du vil se advocate/skeptic bullets hver gang
MAX_CHARS = 1200        # hvor meget claimtekst der printes (resten kan stadig ses i csv)

def clip(s: str, n: int) -> str:
    s = "" if s is None else str(s)
    return s if len(s) <= n else s[:n] + " ...[truncated]"

def main():
    df = pd.read_csv(CSV_PATH)

    # ensure needed columns exist
    needed = ["doc_id", "text", "agent_judge_suggested", "agent_judge_confidence", "agent_judge_rationale"]
    for c in needed:
        if c not in df.columns:
            raise ValueError(f"Missing column '{c}' in {CSV_PATH}. Found: {list(df.columns)}")

    # add human column if missing
    if "is_green_human_a3" not in df.columns:
        df["is_green_human_a3"] = ""
    if "notes_a3" not in df.columns:
        df["notes_a3"] = ""

    # iterate rows
    for i in range(len(df)):
        # skip already labeled
        if str(df.at[i, "is_green_human_a3"]).strip() != "":
            continue

        doc_id = df.at[i, "doc_id"]
        text = str(df.at[i, "text"])
        sug = df.at[i, "agent_judge_suggested"]
        conf = df.at[i, "agent_judge_confidence"]
        rat = df.at[i, "agent_judge_rationale"]

        print("\n" + "=" * 100)
        print(f"Row {i+1}/{len(df)} | doc_id: {doc_id}")
        print("-" * 100)
        print(clip(text, MAX_CHARS))
        print("-" * 100)
        print(f"Agent Judge suggested: {sug} | confidence: {conf}")
        print(f"Judge rationale: {rat}")

        if SHOW_ADV_SKEP:
            if "agent_advocate" in df.columns:
                print("\nAdvocate:\n", df.at[i, "agent_advocate"])
            if "agent_skeptic" in df.columns:
                print("\nSkeptic:\n", df.at[i, "agent_skeptic"])

        print("-" * 100)

        while True:
            ans = input("Your FINAL label is_green_human_a3 (0/1) [s=skip, q=quit]: ").strip().lower()
            if ans in {"0", "1"}:
                df.at[i, "is_green_human_a3"] = int(ans)
                df.to_csv(CSV_PATH, index=False)
                print("Saved ✅")
                break
            if ans == "s":
                df.at[i, "notes_a3"] = "skipped"
                df.to_csv(CSV_PATH, index=False)
                print("Skipped (saved note) ✅")
                break
            if ans == "q":
                df.to_csv(CSV_PATH, index=False)
                print("Quit (progress saved).")
                return
            print("Please type 0, 1, s, or q.")

    print("\nDONE. All available rows labeled (or skipped).")
    print("Updated:", CSV_PATH)

if __name__ == "__main__":
    main()
# Out:
# ====================================================================================================
# Row 1/100 | doc_id: 8593474
# ----------------------------------------------------------------------------------------------------
# 1. A method for reading data from a tiled organized memory, comprising: in response to receiving one tiled-X read request to read two cache line size units from a tiled organized memory in the X-direction, requesting two cache lines from the tiled-X organized memory without fragmenting the received tiled-X read request into more than the one tiled-X read request; allocating the two cache lines in parallel; reading data associated with the two cache lines from a data cache in parallel; and returning, in parallel, data associated with the two requested cache lines, wherein the allocating, reading, and returning of the data is accomplished in one clock cycle.
# ----------------------------------------------------------------------------------------------------
# Agent Judge suggested: 0 | confidence: low
# Judge rationale: The claim describes a method for data reading and processing, focusing on speed and parallelization. It contains no explicit references to environmental benefits such as emissions reduction, renewable energy, or resource conservation. Therefore, it does not meet the criteria for green technology based solely on the provided text.
#
# Advocate:
#  Here's an argument for classifying this claim as green technology, based solely on the provided text:
#
# *   **“Reading data”** – The core action described is data reading, which inherently reduces the need for energy-intensive data processing and storage, potentially leading to lower energy consumption.
# *   **“Allocating the two cache lines in parallel; reading data associated with the two cache lines from a data cache in parallel; and returning, in parallel, data associated with the two requested cache lines”** – This parallel processing suggests optimized resource utilization, which can translate to reduced energy demands compared to sequential processing.
# *   **“One clock cycle”** –  The claim highlights a significant speed improvement, implying a more efficient system that requires less time to complete a task, and therefore less energy.
#
# No strong green evidence found.
#
# Skeptic:
#  Okay, here’s my skeptical assessment of this claim, arguing against its classification as green technology:
#
# *   **Lack of Environmental Impact:** The claim describes a “method for reading data” from memory. There is absolutely no mention of, nor any implication of, any climate, energy, or environmental benefit.
# *   **Focus on Performance Optimization:** The entire description centers on “parallel” processing and “one clock cycle.” This is purely about improving the *speed* and *efficiency* of data access – a standard optimization technique applicable to virtually any computing system.
# *   **Vague and Generic Language:** Phrases like “tiled organized memory” and “data cache” are incredibly broad and don’t suggest any specific environmental application. They are technical terms, not indicators of green technology.
# *   **No Mention of Renewables, Emissions, or Resources:** Crucially, the claim doesn’t touch upon any aspect related to renewable energy, emissions reduction, resource conservation, or any other environmental concern.
#
# Essentially, this is a description of a standard data processing technique, and it has no connection to green technology.
# ----------------------------------------------------------------------------------------------------
# Saved ✅
#
# ====================================================================================================
# Row 2/100 | doc_id: 9617453
# ----------------------------------------------------------------------------------------------------
# 1. A solvent-free aqueous polyurethane dispersion comprising non-crystalline polyurethane polymer comprising the reaction product of: (A) an organic solvent-free isocyanate-terminated prepolymer having a bulk viscosity between 500 centipoise to 15,000 centipoise at 80° C. and comprising the reaction product of: (i) at least one polyisocyanate selected from the group consisting of aliphatic and cycloaliphatic polyisocyanates and mixtures thereof; (ii) at least one polyol, wherein said at least one polyol is selected from the group consisting of polyether polyols, polycarbonate polyols and mixtures thereof; (iii) at least one isocyanate-reactive compound comprising one or more ionic groups or potential ionic groups per molecule; and (iv) at least one isocyanate chain terminating agent comprising at least one carboxylic acid or sulfonic acid group per molecule and one isocyanate-reactive group per molecule, and at least one isocyanate chain terminating agent comprising hydrophilic ethylene oxide units and one isocyanate-reactive group per molecule and having a number average molecular weight of 250 to 600 g/mol, wherein said chain terminating agent comprising hydrophilic ethylene oxid ...[truncated]
# ----------------------------------------------------------------------------------------------------
# Agent Judge suggested: 1 | confidence: medium
# Judge rationale: The claim explicitly details a ‘solvent-free aqueous polyurethane dispersion’ and utilizes ‘solvent-free water’ as a key component. Furthermore, the inclusion of ‘hydrophilic ethylene oxide units’ and a ‘neutralizing agent’ suggests a formulation designed to reduce or eliminate the need for additional solvents or additives, aligning with green chemistry principles focused on reducing environmental impact.
#
# Advocate:
#  Here’s an argument for classifying this claim as green technology, based solely on the provided text:
#
# *   **“Solvent-free aqueous polyurethane dispersion”**: The core of the invention is a *solvent-free* dispersion. Eliminating solvents is a direct environmental benefit, reducing volatile organic compound (VOC) emissions and associated air pollution.
# *   **“Non-crystalline polyurethane polymer”**: While not explicitly stated, non-crystalline polymers often exhibit improved durability and potentially reduced material usage, aligning with sustainable practices.
# *   **“at least one isocyanate-reactive compound comprising one or more ionic groups or potential ionic groups per molecule”**: The inclusion of ionic groups suggests a formulation designed for enhanced stability and potentially reduced material usage through improved crosslinking, a key factor in sustainable material design.
# *   **“at least one chain terminating agent comprising hydrophilic ethylene oxide units”**: The use of hydrophilic ethylene oxide units indicates a formulation designed to improve water compatibility and dispersion stability – a crucial factor in reducing the need for additional solvents or additives.
# *   **“solvent-free water”**: The use of water as the primary dispersing medium is a fundamental element of green chemistry
#
# Skeptic:
#  Here’s an argument against classifying this patent claim as green technology, based solely on the provided text:
#
# *   “Solvent-free aqueous polyurethane dispersion” – While “solvent-free” suggests a reduction in volatile organic compounds (VOCs), it doesn’t inherently demonstrate a *climate* or *environmental* benefit. It simply avoids one type of solvent.
# *   “Non-crystalline polyurethane polymer” – This describes a material property, not a technology addressing environmental issues. The term “non-crystalline” offers no indication of green attributes.
# *   “Comprising the reaction product of…isocyanates and polyols” – The claim focuses on the *composition* of a polymer, without detailing how this polymer contributes to a greener outcome. It’s a materials description, not a technology.
# *   “Neutralizing agent that reacts with the potential ionic groups” – This describes a process for modifying the polymer, again without specifying an environmental impact.
# *   “Chain extending agent comprising an organic polyamine” – Similar to the above, this is a component detail, not a green technology itself.
#
# Essentially, the claim describes a *type* of
# ----------------------------------------------------------------------------------------------------
# Saved ✅
#
# ====================================================================================================
# Row 3/100 | doc_id: 8618928
# ----------------------------------------------------------------------------------------------------
# 1. A method for wireless health monitoring of a locator beacon mechanically attached to a housing of a data recorder provided to record specific performance parameters of a vehicle, comprising: coupling a first Transponder and Sensor Module (TSM) directly to or adjacent to said locator beacon such that at least one condition of said locator beacon or a battery of said locator beacon can be remotely monitored with assistance of the first TSM, wherein the first TSM comprises a first electronic circuit with a power source separate from the battery of the locator beacon and wherein said coupling is provided by at least one of periodically detecting said condition by said first TSM; wirelessly transmitting, from said first TSM to a wireless device electrically coupled to a second electronic circuit of the data recorder and located in proximity to said first TSM, a signal including information describing said condition detected by said first TSM; communicating the information from the wireless device to the second electronic circuit via a wired connection; using the information by the second electronic circuit to detect a data recorder failure.
# ----------------------------------------------------------------------------------------------------
# Agent Judge suggested: 0 | confidence: low
# Judge rationale: The claim focuses solely on vehicle diagnostics and data monitoring, with no explicit mention of environmental benefits such as emissions reduction, energy efficiency, or resource conservation. Phrases like 'performance parameters of a vehicle' and 'detect a data recorder failure' relate to vehicle operation, not green technologies.
#
# Advocate:
#  Here's an argument for classifying this claim as green technology, based solely on the provided text:
#
# *   **Remote Monitoring of Vehicle Battery:** The claim explicitly states “at least one condition of said locator beacon or a battery of said locator beacon can be remotely monitored.” Monitoring battery health is directly relevant to extending the lifespan of electric vehicle batteries, a core element of reducing emissions.
# *   **Data Recorder Failure Detection:** The system’s purpose – detecting a data recorder failure – suggests a focus on maintaining the operational efficiency of a vehicle, which aligns with broader energy efficiency goals.
# *   **Wireless Transmission & Data Collection:** The use of “wirelessly transmitting” implies a system designed to minimize physical connections and potentially reduce the need for frequent maintenance or replacement of components, contributing to sustainability.
# *   **Performance Parameters:** Recording “specific performance parameters of a vehicle” suggests an effort to optimize vehicle operation, which can translate to reduced fuel consumption and emissions.
#
# No strong green evidence found.
#
# Skeptic:
#  Here's an argument against classifying this claim as green technology, based solely on the provided text, presented from a skeptical perspective:
#
# *   “Wireless health monitoring of a locator beacon” – This describes a system for tracking a *vehicle’s* performance parameters, not addressing any environmental issue. The focus is entirely on diagnostics and failure detection.
# *   “mechanically attached to a housing of a data recorder” – This simply details the physical connection of a sensor, offering no indication of a green benefit.
# *   “coupling a first Transponder and Sensor Module (TSM) directly to or adjacent to said locator beacon” – The description is purely functional, detailing a sensor connection without any mention of environmental impact.
# *   “wirelessly transmitting, from said first TSM to a wireless device” – The emphasis on wireless transmission is irrelevant to environmental benefits and could simply be a convenient method of data transfer.
# *   “detect a data recorder failure” – This is a standard diagnostic function, with no connection to climate, energy, or environmental protection.
#
# Do you want me to analyze another patent claim?
# ----------------------------------------------------------------------------------------------------
# Saved ✅
#
# ====================================================================================================
# Row 4/100 | doc_id: 9327149
# ----------------------------------------------------------------------------------------------------
# 1. An aerial fire suppression system for mounting to a helicopter fuselage, said system comprising: a tank divided into at least two compartments by a vertically extending barrier, wherein the base of each compartment comprises an outwardly opening door; at least one baffle positioned within each of the compartments, wherein the baffles extend vertically and are configured to limit oscillations of a load from a front of the tank to a back of the tank; wherein at least one of the baffles includes at least one cut-out provided for allowing fluid flow there through a retractable snorkel unit attached to the tank for transferring liquid from a liquid source into the compartments; an inflatable seal for bridging a junction between at least a portion of a circumference of the outwardly opening door and the tank; and a cyclic comprising one or more inputs for independently operating at least the outwardly opening doors, the retractable snorkel and the inflatable seals.
# ----------------------------------------------------------------------------------------------------
# Agent Judge suggested: 0 | confidence: low
# Judge rationale: The claim describes an aerial fire suppression system, which addresses a negative environmental impact (wildfires) but does not explicitly state a climate or environmental benefit. Phrases like 'transferring liquid from a liquid source' and 'limiting oscillations' are related to the system's function, not its environmental impact.
#
# Advocate:
#  Here's an argument for classifying this claim as green technology, based solely on the provided text:
#
# *   “Aerial fire suppression system” directly addresses a significant environmental threat: wildfires. Wildfires release massive amounts of carbon dioxide and other pollutants, so suppressing them is inherently a climate-positive action.
# *   “Retractable snorkel unit for transferring liquid from a liquid source into the compartments” suggests a system utilizing a water-based suppression method, which is a greener alternative to traditional fire suppression techniques that often rely on chemical agents.
# *   The system’s design, including “baffles to limit oscillations,” implies a focus on efficient use of suppressant – reducing the overall volume of chemicals needed to achieve fire suppression.
# *   “Inflatable seal for bridging a junction” suggests a system designed to minimize leakage, further optimizing the use of the suppressant and reducing environmental impact.
#
# No strong green evidence found.
#
# Skeptic:
#  Here's an argument against classifying this claim as green technology, based solely on the provided text:
#
# *   **Focus on Fire Suppression, Not Environmental Remediation:** The claim explicitly describes an “aerial fire suppression system,” indicating its purpose is to combat wildfires – a reactive measure, not a proactive solution for environmental problems.
# *   **“Outwardly Opening Doors” and “Retractable Snorkel” Suggests Traditional Firefighting:** The detailed description of “outwardly opening doors” and a “retractable snorkel” points to a conventional approach to firefighting, relying on direct water application, rather than innovative green technologies.
# *   **“Limit Oscillations of a Load” – Primarily Structural Concerns:** The inclusion of “baffles” designed to “limit oscillations” suggests a focus on structural integrity and helicopter performance, not on any environmental benefit.
# *   **“Inflatable Seal” – Standard Engineering Component:** The use of an “inflatable seal” is a common engineering element for sealing and pressure management, without any inherent connection to environmental sustainability.
#
# Essentially, the claim describes a system for a traditional, potentially resource-intensive activity (aerial firefighting) – it doesn
# ----------------------------------------------------------------------------------------------------
# Saved ✅
#
# ====================================================================================================
# Row 5/100 | doc_id: 9359060
# ----------------------------------------------------------------------------------------------------
# 1. A laminated composite radius filler for a composite structure comprising: a stacked ply assembly comprising a plurality of stacks of laminate radius filler plies cut to a desired width and having a desired ply orientation; and, a separate, pre-formed geometric shaped filler element comprising a plurality of plies comprised of a plurality of unidirectional fibers, a unidirectional fiber tape, a prepreg unidirectional tape, a unidirectional composite tow, a slit unidirectional tape, a carbon fiber-reinforced plastic (CFRP) tape, a carbon fiber-reinforced plastic (CFRP) fabric, a prepreg fabric, a woven fabric including a woven carbon fiber fabric, or a combination thereof, the geometric shaped filler element positioned within the laminated composite radius filler at a desired location on a first portion of the stacked ply assembly, the geometric shaped filler element deforming a second portion of the stacked ply assembly stacked over the geometric shaped filler element, such that the laminate radius filler plies of the second portion of the stacked ply assembly change direction and have a component of direction comprising a horizontal direction and a vertical direction, the lamina ...[truncated]
# ----------------------------------------------------------------------------------------------------
# Agent Judge suggested: 0 | confidence: low
# Judge rationale: The claim describes a composite filler for a structural component. While it mentions materials like carbon fiber, it lacks explicit statements regarding emissions reduction, energy efficiency, or any other environmental benefit. The focus is solely on the structural design and manufacturing process of the composite.
#
# Advocate:
#  Here's an argument for classifying this claim as green technology, based solely on the provided text:
#
# *   “laminated composite radius filler” – This suggests a material solution, potentially replacing heavier, less sustainable materials within a composite structure.
# *   “a plurality of unidirectional fibers, a unidirectional fiber tape, a prepreg unidirectional tape, a unidirectional composite tow, a slit unidirectional tape, a carbon fiber-reinforced plastic (CFRP) tape, a carbon fiber-reinforced plastic (CFRP) fabric, a prepreg fabric, a woven fabric including a woven carbon fiber fabric” – Carbon fiber is frequently used in lightweighting applications, which can reduce the energy consumption of vehicles and other systems.
# *   “deforming a second portion of the stacked ply assembly, such that the laminate radius filler plies…change direction” – This implies a structural optimization that could lead to improved material efficiency and reduced material usage, a core element of sustainable design.
# *   “filling the radius filler region” – This suggests a targeted solution to a structural need, potentially replacing a less efficient or more resource-intensive component.
#
# No strong green evidence found.
#
# Skeptic:
#  Here’s an argument against classifying this claim as green technology, based solely on the provided text:
#
# *   “laminated composite radius filler” – This describes a material component within a *composite structure*, which inherently implies the use of materials and manufacturing processes – a focus on material itself, not a solution to environmental problems.
# *   “stacked ply assembly comprising a plurality of stacks of laminate radius filler plies” – The claim details a complex manufacturing process focused on shaping a composite, without any mention of reducing environmental impact.
# *   “geometric shaped filler element comprising a plurality of plies comprised of a plurality of unidirectional fibers…” – The description centers on the *construction* of a composite, utilizing materials like carbon fiber – a resource with significant environmental concerns related to extraction and processing.
# *   “shape substantially corresponding to a radius filler region of the composite structure” – This simply states a functional design element within a larger structure, lacking any assertion of an environmental benefit.
# *   “deforming a second portion of the stacked ply assembly” – This describes a mechanical process, not a technology aimed at mitigating environmental issues.
#
# In short, the claim focuses on *how*
# ----------------------------------------------------------------------------------------------------
# Saved ✅
#
# ====================================================================================================
# Row 6/100 | doc_id: 9349292
# ----------------------------------------------------------------------------------------------------
# 1. A vehicle system comprising: at least one sensor configured to output a range signal representing a distance from a host vehicle to a front vehicle and a range-rate signal representing range-rate information of the front vehicle relative to the host vehicle; and a processing device programmed to output an alarm signal based on the range signal and range-rate signal relative to a predetermined envelope defined as a function of the distance from the host vehicle and the range-rate information, and whether a driver of the host vehicle is determined to be distracted.
# ----------------------------------------------------------------------------------------------------
# Agent Judge suggested: 0 | confidence: low
# Judge rationale: The claim focuses on vehicle safety and driver distraction, utilizing range and range-rate signals to prevent collisions. There is no explicit mention of emissions reduction, energy efficiency, or any other environmental benefit within the claim text.
#
# Advocate:
#  Here's an argument for classifying this claim as green technology, based solely on the provided text:
#
# *   “A vehicle system” – This inherently relates to transportation, a sector with significant environmental impact.
# *   “range signal representing a distance from a front vehicle” – This directly addresses reducing collisions, which can lead to secondary accidents and wasted energy due to emergency maneuvers.
# *   “range-rate signal representing range-rate information of the front vehicle relative to the host vehicle” –  Optimizing vehicle spacing reduces the need for sudden braking and acceleration, a key factor in fuel efficiency and emissions.
# *   “alarm signal based on the range signal and range-rate signal relative to a predetermined envelope” – This system aims to prevent accidents, which reduces the likelihood of vehicle damage and resource consumption associated with repairs and replacements.
#
# No strong green evidence found.
#
# Skeptic:
#  Okay, here’s my skeptical assessment of this claim, arguing against its classification as green technology:
#
# *   “A vehicle system” – This describes a standard automotive system, focusing solely on driver assistance and safety. It doesn’t inherently address any environmental impact.
# *   “range signal representing a distance…range-rate signal” – These terms relate to improved vehicle control and collision avoidance – a focus on *reducing* accidents, not reducing environmental impact.
# *   “programmed to output an alarm signal based on…predetermined envelope” – The claim emphasizes a system for *preventing* collisions, a reactive measure rather than a proactive environmental solution.
# *   “whether a driver of the host vehicle is determined to be distracted” – This highlights driver monitoring, a safety feature, and doesn’t touch on sustainability.
#
# In short, the claim describes a system for safer driving, which is a valuable improvement but doesn’t represent a green technology.
# ----------------------------------------------------------------------------------------------------
# Saved ✅
#
# ====================================================================================================
# Row 7/100 | doc_id: 9377453
# ----------------------------------------------------------------------------------------------------
# 1. A method for detection of anti-oxidant activity of a test compound, the method comprising: introducing a labeled tRNA into a cell; detecting the subcellular localization of the tRNA over a predetermined period of time, wherein the detection is based on the signal emitted from the labeled tRNA; and detecting a change in the subcellular localization of the labeled tRNA in the cell after exposure of the cell to the test compound, wherein the change is indicative of anti-oxidant induced stress in the cell.
# ----------------------------------------------------------------------------------------------------
# Agent Judge suggested: 0 | confidence: low
# Judge rationale: The claim describes a method for detecting antioxidant activity in cells, focusing on a cellular assay rather than a technology with an explicit environmental benefit. Phrases like "detecting a change in the subcellular localization" and "anti-oxidant induced stress" do not indicate a climate, energy, or environmental benefit.
#
# Advocate:
#  Here's an argument for classifying this claim as green technology, based solely on the provided text:
#
# *   **“detecting a change in the subcellular localization of the labeled tRNA in the cell after exposure of the cell to the test compound”** – This directly relates to assessing cellular stress, which is a key indicator of potential environmental impact and mitigation strategies.
# *   **“anti-oxidant induced stress”** – Antioxidant activity is frequently explored in the context of combating environmental damage caused by oxidative stress – a significant factor in pollution and climate change effects.
# *   **“labeled tRNA”** – The use of labeled molecules for tracking cellular processes suggests a focus on understanding and potentially correcting imbalances within biological systems, which could have implications for environmental remediation.
# *   **“test compound”** – The method is designed to assess the activity of a compound, implying a search for solutions to environmental challenges.
#
# No strong green evidence found.
#
# Skeptic:
#  Here's an argument against classifying this claim as green technology, based solely on the provided text:
#
# *   “detection of anti-oxidant activity of a test compound” – This focuses solely on *measuring* antioxidant properties, not on a demonstrable environmental benefit. It’s a laboratory technique.
# *   “introducing a labeled tRNA into a cell” – The use of a “labeled tRNA” suggests a research tool, not a technology deployed to address a broader environmental issue.
# *   “detecting a change in the subcellular localization of the labeled tRNA in the cell after exposure of the cell to the test compound” – This describes a cellular assay, again, without linking it to any positive environmental impact.
# *   “wherein the change is indicative of anti-oxidant induced stress in the cell” – The phrase “anti-oxidant induced stress” is a negative descriptor, implying a cellular response to damage, not a beneficial environmental outcome.
#
# Essentially, the claim describes a method for *studying* a biological process, not a technology designed to mitigate environmental harm.
# ----------------------------------------------------------------------------------------------------
# Saved ✅
#
# ====================================================================================================
# Row 8/100 | doc_id: 9759300
# ----------------------------------------------------------------------------------------------------
# 1. A transmission for a walk-behind wheeled vehicle, the transmission comprising: at least one casing at least partially housing a driver member, equipped with rotary drive motor means, a rotary driven member in the form of a toothed wheel, continuously engaging with the motor driver member, wheel drive means for driving both wheels of a single pair of wheels of the vehicle, said wheel drive means having wheel drive shaft made in one piece or made up of at least two wheel drive shaft segments in alignment, each of which is suitable for driving a respective wheel of the single pair of wheels of the vehicle, and a clutch mechanism disposed between the wheel drive shaft or each of the wheel drive shaft segments and the driven member, the clutch mechanism or mechanisms being activated by the driven member being driven in rotation in a forwards first rotary drive direction, and deactivatable by the wheel drive shaft or the wheel drive shaft segment with which it co-operates being driven in rotation forwards, when the speed of rotation of the wheel drive shaft or of the wheel drive shaft segment is greater than the speed of rotation of the driven member, the wheel drive shaft or each whe ...[truncated]
# ----------------------------------------------------------------------------------------------------
# Agent Judge suggested: 0 | confidence: low
# Judge rationale: The claim describes a standard transmission for a wheeled vehicle. Phrases like "rotary drive motor means" and "wheel drive means" relate to vehicle mechanics, but there is no explicit mention of environmental benefits such as emissions reduction, energy efficiency, or renewable energy sources. The claim focuses solely on the functional components of the transmission.
#
# Advocate:
#  Here’s an argument for classifying this claim as green technology, based solely on the provided text:
#
# *   “rotary drive motor means” – This explicitly references a motor, a key component in driving renewable energy systems and reducing reliance on fossil fuels.
# *   “suitable not only for driving the driven member in rotation in the forwards direction, but also for driving the driven member in rotation in a backwards second direction that is opposite to said first direction of rotation” – The ability to rotate in *both* directions suggests a vehicle that could potentially be used in a variety of applications, including those related to energy efficiency or alternative transportation solutions.
# *   “wheel drive means for driving both wheels of a single pair of wheels of the vehicle” – While basic, this implies a vehicle designed for efficient movement, which can contribute to reduced emissions compared to less efficient transportation methods.
#
# No strong green evidence found.
#
# Skeptic:
#  Here's an argument against classifying this claim as green technology, based solely on the provided text, presented from a skeptical perspective:
#
# *   “A transmission for a walk-behind wheeled vehicle” – This describes a standard component for a vehicle, offering no inherent environmental benefit. It simply facilitates movement.
# *   “motor means that can be controlled to rotate in two directions of rotation” – The ability to rotate in reverse is a functional characteristic of a motor, not a green technology.
# *   “suitable not only for driving the driven member in rotation in the forwards direction, but also for driving the driven member in rotation in a backwards second direction that is opposite to said first direction of rotation” – This detail focuses on operational control, again, a standard feature of a motor, without addressing any environmental impact.
# *   “wheel drive shaft made in one piece or made up of at least two wheel drive shaft segments” – This describes a mechanical component with no connection to environmental sustainability.
#
# Essentially, the claim focuses on the mechanics of a vehicle transmission, lacking any explicit mention of emissions reduction, energy efficiency, or any other environmental benefit.
# ----------------------------------------------------------------------------------------------------
# Saved ✅
#
# ====================================================================================================
# Row 9/100 | doc_id: 8870275
# ----------------------------------------------------------------------------------------------------
# 1. A device for reducing aerodynamic drag of a ground vehicle, the device comprising: a tubing having an intake port, an exit port, and a plurality of venturis; and, a compressed air source being fluidly connected to the intake port; wherein the plurality of venturis is disposed between the intake port and the exit port; and, wherein each venturi from among the plurality of venturis has a throat and a venturi opening on an outer periphery of the venturi throat to remove a portion of a fluid from a boundary layer of the ground vehicle.
# ----------------------------------------------------------------------------------------------------
# Agent Judge suggested: 0 | confidence: low
# Judge rationale: The claim focuses solely on 'reducing aerodynamic drag of a ground vehicle' and utilizes 'compressed air' without specifying a sustainable source. There is no explicit mention of emissions reduction, renewable energy, or any other environmental benefit, making it a general efficiency improvement rather than green technology.
#
# Advocate:
#  Here's an argument for classifying this claim as green technology, based solely on the provided text:
#
# *   “reducing aerodynamic drag of a ground vehicle” – This directly addresses improving fuel efficiency, a key component of reducing greenhouse gas emissions from transportation.
# *   “compressed air source being fluidly connected to the intake port” – Utilizing compressed air to manipulate airflow suggests a method of optimizing vehicle performance, which can translate to lower fuel consumption.
# *   “remove a portion of a fluid from a boundary layer” – This describes a technique for streamlining airflow around the vehicle, further contributing to reduced drag and, consequently, energy savings.
# *   “ground vehicle” – The claim’s focus on ground vehicles inherently links to transportation, a significant contributor to global emissions.
#
# No strong green evidence found.
#
# Skeptic:
#  Here's an argument against classifying this claim as green technology, based solely on the provided text:
#
# *   “reducing aerodynamic drag of a ground vehicle” – This focuses solely on *performance* enhancement, not addressing any environmental impact. It’s a purely engineering optimization.
# *   “compressed air source” – The use of compressed air, without specifying its source or impact, introduces a potential energy consumption element that isn’t framed as environmentally beneficial.
# *   “remove a portion of a fluid from a boundary layer” – This describes a mechanism for streamlining airflow, which, while potentially improving fuel efficiency, doesn’t inherently address emissions or broader environmental concerns.
# *   The claim lacks any mention of renewable energy sources, carbon reduction, or any other environmental benefit. It’s purely focused on drag reduction.
#
# Essentially, the claim describes a conventional aerodynamic modification, lacking any explicit green technology attributes.
# ----------------------------------------------------------------------------------------------------
# Saved ✅
#
# ====================================================================================================
# Row 10/100 | doc_id: 9297592
# ----------------------------------------------------------------------------------------------------
# 1. A moisture separator reheater comprising: a horizontal cylindrical body drum having a steam inlet at a bottom of the body drum for receiving steam to be heated and a steam outlet at a top of the body drum for discharging heated steam; end plates formed at both end portions of the body drum in a longitudinal direction thereof, and exposed outside; a moisture removal section for removing moisture in the steam distributed inside the body drum; a heat transfer tube group disposed above the moisture removal section, wherein a heating fluid for heating the steam is distributed in the heat transfer tube group; a heater header arranged to supply the heating fluid to the heat transfer tube group and exhaust outside the heating fluid that has been heat exchanged with the steam; and a partition plate disposed inside the body drum and between the end plates so as to guide the steam from the moisture removal section to the heat transfer tube group; the heat transfer tube group including a plurality of heat transfer tubes each having a forward passage part, a backward passage part, and a bent tube part, the forward and the backward passage parts extending in the longitudinal direction of the  ...[truncated]
# ----------------------------------------------------------------------------------------------------
# Agent Judge suggested: 0 | confidence: low
# Judge rationale: The claim describes a moisture separator reheater, a component within a steam system. Phrases like "heating fluid for heating the steam" and "moisture removal section" relate to operational efficiency within a steam process, but lack explicit statements regarding emissions reduction, renewable energy, or other environmental benefits. The claim focuses solely on the internal design and function of the device.
#
# Advocate:
#  Here's an argument for classifying this claim as green technology, based solely on the provided text:
#
# *   “heating fluid for heating the steam” – This explicitly describes a system designed to *increase* the temperature of a fluid, suggesting a potential application in energy efficiency, particularly if the heating fluid is derived from a renewable source.
# *   “moisture removal section for removing moisture in the steam” – Moisture removal directly relates to improving the efficiency of steam usage, a key element in energy production and reducing wasted energy.
# *   “heat transfer tube group” – Heat transfer is central to energy efficiency technologies, optimizing the transfer of thermal energy.
# *   “partition plate disposed inside the body drum and between the end plates so as to guide the steam from the moisture removal section to the heat transfer tube group” – This suggests a system designed to optimize steam flow, which can contribute to greater energy efficiency.
#
# No strong green evidence found.
#
# Skeptic:
#  Here's an argument against classifying this claim as green technology, based solely on the provided text:
#
# *   “A moisture separator reheater” – This describes a component within a *conventional* steam system, focusing solely on improving steam separation and heating. There’s no mention of any environmental benefit.
# *   “heating fluid for heating the steam” – The claim simply details a system for *increasing* the temperature of steam, a process with inherent energy consumption regardless of the application.
# *   “exposed outside” – This simply describes the physical design of the equipment, offering no indication of any green function.
# *   “guide the steam from the moisture removal section to the heat transfer tube group” – This is a functional description of a steam system, not a technology designed to reduce environmental impact.
#
# Essentially, the claim details a standard, established piece of equipment within a steam generation process – it doesn’t address any climate, energy, or environmental benefit.
# ----------------------------------------------------------------------------------------------------
# Saved ✅
#
# ====================================================================================================
# Row 11/100 | doc_id: 9494626
# ----------------------------------------------------------------------------------------------------
# 1. A constant period signal monitoring circuit for monitoring a constant period signal that is output periodically when a control processor operating according to a program is normal from the outside of the control processor, the monitoring circuit comprising: a signal input terminal that receives the constant period signal; an edge detection section that detects a change of the constant period signal appearing at the signal input terminal from a low level to a high level or from a high level to a low level as an edge of the constant period signal; and a time measuring section that measures a length of the time during which a state of not detecting the edge continues on the basis of an output of the edge detection section and outputs an abnormality detection signal in a case that the measured time exceeds a threshold value.
# ----------------------------------------------------------------------------------------------------
# Agent Judge suggested: 0 | confidence: low
# Judge rationale: The claim describes a monitoring circuit for a control processor, focusing on detecting abnormalities and measuring time. There is no explicit mention of environmental benefits such as emissions reduction, renewable energy, or resource conservation, making it unsuitable for classification as green technology based solely on the claim text.
#
# Advocate:
#  Here's an argument for classifying this claim as green technology, based solely on the provided text:
#
# *   **“Monitoring a constant period signal”**: This suggests a system designed to observe and potentially optimize a process, implicitly aiming for efficiency – a core element of green technology.
# *   **“Abnormality detection signal”**: The circuit’s purpose is to identify deviations from normal operation. This implies a focus on preventing issues that could lead to wasted resources or environmental impact.
# *   **“Output periodically when a control processor operating according to a program is normal”**:  The claim suggests a system designed to ensure the normal operation of a processor, which could be related to energy-efficient processes or systems.
# *   **“Time measuring section that measures a length of the time during which a state of not detecting the edge continues”**: This indicates a system designed to optimize a process, which is a key component of green technology.
#
# No strong green evidence found.
#
# Skeptic:
#  Okay, here’s my skeptical assessment of this claim, arguing against its classification as green technology:
#
# *   **Lack of Environmental Impact:** The claim describes a “constant period signal monitoring circuit.” This has absolutely no connection to climate, energy, or environmental benefits. It’s purely a diagnostic tool for a control processor.
# *   **Focus on Operational Monitoring:** The description centers on “monitoring a constant period signal” and “abnormality detection.” This is a standard, generic function for ensuring system reliability, not a technology designed to address environmental issues.
# *   **“Threshold Value” is Neutral:** The inclusion of a “threshold value” simply indicates a parameter for the circuit’s operation, adding no element of environmental benefit or mitigation.
# *   **No Mention of Sustainability:** The claim doesn’t contain any language related to renewable energy, emissions reduction, resource conservation, or any other environmental objective.
#
# Essentially, this is a purely functional circuit design – a component for a control system – and bears no discernible relationship to green technology.
# ----------------------------------------------------------------------------------------------------
# Saved ✅
#
# ====================================================================================================
# Row 12/100 | doc_id: 8751695
# ----------------------------------------------------------------------------------------------------
# 1. A hybrid storage device comprising: a first storage part comprising an interface device based on a first standard; a second storage part comprising an interface device based on a second standard; and a connector for interface devices configured to be shared by the first storage part and the second storage part and comprises a plurality of pins, wherein the connector comprises a power supply pin, and wherein power lines of the interface device of the first standard and the interface device of the second standard are commonly connected to the power supply pin, and wherein, in the connector, a manufacturing diagnostic pin and a device present pin defined in the SATA standard are used as D+ and D− line pins defined in the USB standard.
# ----------------------------------------------------------------------------------------------------
# Agent Judge suggested: 0 | confidence: low
# Judge rationale: The claim describes a hybrid storage device utilizing existing standards (SATA and USB) and focuses on connector design. There is no explicit mention of any environmental benefit, such as emissions reduction, energy efficiency, or waste reduction, making it unsuitable for classification as green technology based solely on the provided text.
#
# Advocate:
#  Here's an argument for classifying this claim as green technology, based solely on the provided text:
#
# *   “A hybrid storage device” – This suggests a system designed to optimize storage, potentially reducing the need for redundant storage solutions and therefore, energy consumption.
# *   “commonly connected to the power supply pin” – This indicates a focus on efficient power utilization, a key element of energy efficiency and reducing energy waste.
# *   “manufacturing diagnostic pin and a device present pin defined in the SATA standard are used as D+ and D− line pins defined in the USB standard” – Utilizing existing standards (SATA and USB) implies an attempt to leverage established, potentially optimized technologies, which can contribute to reduced resource consumption and environmental impact.
#
# No strong green evidence found.
#
# Skeptic:
#  Okay, here’s my skeptical assessment of this claim, arguing against its classification as green technology:
#
# *   **Vague "Hybrid Storage":** The claim simply describes a “hybrid storage device,” a term that lacks any specific environmental benefit. It doesn’t mention reducing energy consumption, utilizing renewable sources, or addressing any environmental issue.
# *   **Focus on Standardization & Compatibility:** The entire description centers on “interface devices based on a first standard” and “a second standard,” and “compatibility.” This highlights interoperability, not a green innovation.
# *   **“Connector” – Hardware-Centric:** The core of the invention is a “connector” with “pins” and “power supply pin.” This is purely a hardware solution for connecting devices, with no stated environmental impact.
# *   **SATA & USB References:** Referencing “SATA standard” and “USB standard” further emphasizes the claim’s focus on existing technology and compatibility, not a novel green solution.
# *   **Diagnostic Pins – Red Herring:** The inclusion of “manufacturing diagnostic pin” and “device present pin” is a technical detail that doesn’t contribute to any environmental benefit
# ----------------------------------------------------------------------------------------------------
# Saved ✅
#
# ====================================================================================================
# Row 13/100 | doc_id: 8956710
# ----------------------------------------------------------------------------------------------------
# ...
#
# Essentially, this claim describes a technical improvement in wireless communication, lacking any connection to environmental sustainability.
# ----------------------------------------------------------------------------------------------------
# Saved ✅
#
# ====================================================================================================
# Row 97/100 | doc_id: 9098438
# ----------------------------------------------------------------------------------------------------
# 1. A method of scaling voltage in an integrated circuit, the method comprising: performing calibration of a functional module controlled by the integrated circuit periodically at a non-zero rate T1; monitoring at least one operating performance parameter on the integrated circuit to determine when a threshold is reached; initiating a change to an operating voltage for a portion of the integrated circuit in response to reaching the threshold; and increasing the rate of performing calibration to a rate T2 higher than rate T1 for a window of time W in response to initiating the change in operating voltage, after which the rate of performing calibration is returned to the rate T1.
# ----------------------------------------------------------------------------------------------------
# Agent Judge suggested: 0 | confidence: low
# Judge rationale: The claim describes a method for voltage scaling and calibration within an integrated circuit. The text does not contain any explicit references to environmental benefits such as emissions reduction, energy efficiency in a broader context, or any other green technologies. The focus is solely on internal circuit performance optimization.
#
# Advocate:
#  Here's an argument for classifying this claim as green technology, based solely on the provided text:
#
# *   **“Calibration of a functional module”**: This suggests optimizing performance, which can inherently lead to reduced energy consumption within the integrated circuit – a core element of energy efficiency.
# *   **“Monitoring at least one operating performance parameter”**:  The act of monitoring implies a focus on efficiency and identifying areas for improvement, directly relating to reducing resource usage.
# *   **“Increasing the rate of performing calibration to a rate T2 higher than rate T1”**: This dynamic adjustment based on performance suggests a system designed to minimize energy waste and maximize operational effectiveness.
# *   **“Change to an operating voltage for a portion of the integrated circuit”**: Voltage optimization is a key aspect of energy efficiency, reducing power consumption.
#
# No strong green evidence found.
#
# Skeptic:
#  Okay, here’s my skeptical assessment of this claim, arguing against its classification as green technology:
#
# *   **Lack of Environmental Impact:** The claim describes “scaling voltage in an integrated circuit.” This has absolutely no connection to climate change, emissions reduction, or any other environmental benefit. It’s purely an internal electronic process.
# *   **“Calibration” is Vague and Doesn’t Imply Green:** The term “calibration” is used without specifying its environmental relevance. Calibration of *anything* doesn’t automatically equate to green technology.
# *   **Focus on Performance, Not Sustainability:** The claim centers on “monitoring at least one operating performance parameter” and “increasing the rate of performing calibration.” These are optimization goals within a circuit, not solutions for environmental problems.
# *   **Technical Process, Not Green Solution:** The entire description details a technical adjustment within a device. It’s a process for improving performance, not a technology designed to address environmental challenges.
# *   **“Rate T1” and “Rate T2” are Irrelevant:** The specific rates (T1 and T2) are simply technical specifications and contribute nothing to the claim’s
# ----------------------------------------------------------------------------------------------------
# Saved ✅
#
# ====================================================================================================
# Row 98/100 | doc_id: 8503188
# ----------------------------------------------------------------------------------------------------
# 1. A mountable electronic circuit module comprising: a baseboard including a ferrite material; a first mountable electronic component including at least one first external connection electrode, the first mountable electronic component being mounted on a surface of the baseboard via the at least one first external connection electrode; at least one electrode provided on an external surface of the first mountable electronic component and defining at least one module connection electrode arranged to mount the electronic circuit module to a separate circuit board; and a second mountable electronic component having a height less than a height of the first mountable electronic component; wherein the second mountable electronic component includes at least one second external connection electrode that is connected to the at least one module connection electrode via an external surface of the baseboard; and the second mountable electronic component is a DC-DC converter IC that is mounted on the surface of the baseboard on which the first mountable electronic component is mounted.
# ----------------------------------------------------------------------------------------------------
# Agent Judge suggested: 0 | confidence: low
# Judge rationale: The claim describes a DC-DC converter IC and its mounting on a circuit board. While DC-DC converters can be part of energy-efficient systems, the claim itself does not explicitly state or imply any climate, energy, or environmental benefit. The description focuses solely on the construction and components of the module.
#
# Advocate:
#  Here's an argument for classifying this claim as green technology, based solely on the provided text:
#
# *   **DC-DC Converter IC:** The claim explicitly states the second mountable electronic component is a “DC-DC converter IC.” DC-DC converters are frequently utilized in renewable energy systems (solar, wind) to manage voltage fluctuations and improve energy efficiency – a core element of green technology.
# *   **Mountable Electronic Circuit Module:** The design suggests a compact, integrated solution. This could lead to reduced material usage and potentially lower energy consumption in electronic devices, aligning with green technology principles.
# *   **External Connection Electrodes:** The use of external connection electrodes implies a modular design, potentially facilitating easier repair, upgrades, and component replacement, extending the lifespan of the device and reducing electronic waste – a key aspect of sustainability.
# *   **Ferrite Material:** The inclusion of ferrite material suggests a focus on electromagnetic compatibility, which can improve the efficiency of electrical systems, reducing energy loss and contributing to energy conservation.
#
# No strong green evidence found.
#
# Skeptic:
#  Here's an argument against classifying this claim as green technology, based solely on the provided text:
#
# *   **Lack of Explicit Environmental Benefit:** The claim describes a “DC-DC converter IC” and its mounting. There’s absolutely no mention of any climate, energy, or environmental benefit – such as emissions reduction, renewable energy, or resource conservation.
# *   **Focus on Component Assembly:** The entire description centers on the *construction* of an electronic circuit module. It details materials (ferrite) and connections, but these are purely functional aspects of electronics design, not a green technology.
# *   **“Mountable” is Redundant:** The term “mountable electronic circuit module” is simply descriptive of the product’s form factor and doesn’t inherently imply any environmental advantage.
# *   **DC-DC Converter – A Standard Component:** The inclusion of a DC-DC converter is a common electronic component, and its function (voltage conversion) doesn’t, on its own, constitute green technology.
#
# Essentially, the claim focuses on a standard electronic component and its assembly, lacking any indication of a positive environmental impact.
# ----------------------------------------------------------------------------------------------------
# Saved ✅
#
# ====================================================================================================
# Row 99/100 | doc_id: 9540344
# ----------------------------------------------------------------------------------------------------
# 1. A method for producing a compound of formula (II-3) or a salt thereof: the method comprising reacting a compound of formula (VI): in a solvent in a presence of a phosphine reagent and an azo reagent, wherein R
# ----------------------------------------------------------------------------------------------------
# Agent Judge suggested: 0 | confidence: low
# Judge rationale: The claim describes a general method for producing a compound based on chemical reaction conditions. It lacks any explicit mention of environmental benefits such as emissions reduction, renewable energy, or waste management. The presence of 'phosphine reagent' and 'azo reagent' is simply a description of reactants, not an indication of a green technology.
#
# Advocate:
#  Here's an argument for classifying this claim as green technology, based solely on the provided text:
#
# *   **“phosphine reagent”**: Phosphine reagents are increasingly utilized in carbon capture technologies, specifically for absorbing CO2 from industrial emissions. This suggests a potential link to emissions reduction.
# *   **“azo reagent”**: Azo reagents can be involved in catalytic processes, and some catalytic processes are being developed for converting waste streams into valuable materials – aligning with recycling efforts.
# *   **“producing a compound of formula (II-3) or a salt thereof”**: The creation of a new compound, particularly if it has an environmental application (e.g., a catalyst for a green process), could represent a step towards sustainable material production.
# *   **“solvent”**: The use of a solvent, while needing further context, could be part of a process designed to minimize waste or utilize environmentally benign solvents.
#
# No strong green evidence found.
#
# Skeptic:
#  Okay, here’s my skeptical assessment of this patent claim, arguing against its classification as green technology:
#
# *   **Vague Compound Production:** The claim simply describes “producing a compound of formula (II-3) or a salt thereof.” This lacks any specific mention of environmental benefit. It doesn’t address emissions, resource use, or waste reduction.
# *   **Generic Reaction Conditions:** The description of “reacting a compound of formula (VI) in a solvent in the presence of a phosphine reagent and an azo reagent” is entirely standard chemical synthesis terminology. It provides no indication of a novel or environmentally beneficial process.
# *   **Lack of Environmental Outcome:** There’s absolutely no mention of reducing pollution, conserving energy, utilizing renewable resources, or addressing any environmental challenge. The claim focuses solely on the *method* of production, not its impact.
# *   **“R” Placeholder:** The inclusion of “R” suggests a variable component, further obscuring the specific nature of the compound being produced and preventing any assessment of its potential environmental implications.
# *   **Reliance on Standard Reagents:** The use of “phosphine reagent” and “azo reagent”
# ----------------------------------------------------------------------------------------------------
# Saved ✅
#
# ====================================================================================================
# Row 100/100 | doc_id: 9692713
# ----------------------------------------------------------------------------------------------------
# 1. A network system for improving network communication performance between at least a first client site and a second client site, wherein the first client site and the second client site are at a distance from one another that is such that would usually require long haul network communication, the system comprising: at least one client site network component implemented at least at the first client site, the client site network component bonding or aggregating one or more diverse network connections so as to configure a bonded/aggregated connection that has increased throughput; at least one network server component configured to connect to the client site network component using the bonded/aggregated connection, the network server component including at least one concentrator element implemented at a network access point to at least one network, the network server component automatically terminating the bonded/aggregated connection and passing data traffic to the network access point to the at least one network; a virtual edge connection providing at least one of transparent lower-link encryption and lower-link encapsulation using a common access protocol for the bonded/aggregate ...[truncated]
# ----------------------------------------------------------------------------------------------------
# Agent Judge suggested: 0 | confidence: low
# Judge rationale: The claim focuses solely on improving network communication performance and efficiency, without explicitly stating or implying any environmental benefits such as emissions reduction or energy conservation. Phrases like "increased throughput" and "long haul network path" relate to performance optimization, not green technology.
#
# Advocate:
#  Here's an argument for classifying this claim as green technology, based solely on the provided text:
#
# *   “increased throughput” – This directly implies optimizing network communication, which can reduce the energy consumption associated with transmitting data over long distances – a core element of reducing carbon emissions from network infrastructure.
# *   “virtual edge connection providing at least one of transparent lower-link encryption and lower-link encapsulation” –  Reducing data transmission inefficiencies through optimized protocols contributes to energy savings and a more sustainable network.
# *   “managed network overlay that incorporates the virtual edge connection and at least one long haul network path” – By streamlining long-haul communication, the system inherently minimizes the energy required for data transport, aligning with climate-friendly practices.
#
# No strong green evidence found.
#
# Skeptic:
#  Here's an argument against classifying this claim as green technology, based solely on the provided text, presented from a skeptical perspective:
#
# *   “Improving network communication performance between at least a first client site and a second client site” – This description focuses solely on *performance*, lacking any mention of environmental impact or benefit. It’s a purely technical optimization.
# *   “Bonding or aggregating one or more diverse network connections” – While efficient, this simply describes a networking technique with no stated purpose related to sustainability.
# *   “Virtual edge connection providing at least one of transparent lower-link encryption and lower-link encapsulation” – This describes security features, again, without linking to any environmental outcome.
# *   “Managed network overlay that incorporates the virtual edge connection and at least one long haul network path carried over the at least one network” – The claim emphasizes *longer network paths*, which inherently suggests increased data transmission and potentially higher energy consumption, not a reduction.
#
# Essentially, the claim describes a more efficient way to transmit data, but provides no evidence of a green benefit.
# ----------------------------------------------------------------------------------------------------
# Saved ✅
#
# DONE. All available rows labeled (or skipped).
# Updated: hitl_green_100_a3-hitl.csv

# %%
import os
import re
import numpy as np
import pandas as pd
import torch

from datasets import Dataset
from transformers import (
    AutoTokenizer,
    AutoModelForSequenceClassification,
    TrainingArguments,
    Trainer,
    DataCollatorWithPadding,
)
from sklearn.metrics import precision_recall_fscore_support


# -------------------- CONFIG --------------------
PARQUET_PATH = "patents_50k_green.parquet"
A3_CSV_PATH = "hitl_green_100_a3.csv"

BASE_MODEL = "AI-Growth-Lab/PatentSBERTa"
OUT_DIR = "models_finetuned_patentsberta_green_a3"
MERGED_OUT = "patents_50k_green_with_gold_a3.parquet"

ID_COL = "doc_id"
TEXT_COL = "text"
SPLIT_COL = "split"
SILVER_LABEL_COL = "is_green_silver"

# A3 human label column (script will auto-detect if needed)
PREFERRED_A3_HUMAN_COL = "is_green_human_a3"  # change if you used another name

# Recommended settings
MAX_LEN = 256
EPOCHS = 1
LR = 2e-5
TRAIN_BS = 16
EVAL_BS = 32
SEED = 42


# -------------------- DEVICE --------------------
if torch.backends.mps.is_available():
    DEVICE = "mps"
elif torch.cuda.is_available():
    DEVICE = "cuda"
else:
    DEVICE = "cpu"
print("Using device:", DEVICE)


def clean_binary_label(x):
    """Convert 0/1, 0.0/1.0, ' 1 ' to int. Return None if invalid/empty."""
    if x is None or (isinstance(x, float) and np.isnan(x)):
        return None
    s = str(x).strip()
    if s == "":
        return None
    if re.fullmatch(r"[01](\.0+)?", s):
        return int(float(s))
    return None


def compute_metrics(eval_pred):
    # Works on old/new transformers
    if hasattr(eval_pred, "predictions"):
        logits = eval_pred.predictions
        labels = eval_pred.label_ids
    else:
        logits, labels = eval_pred

    preds = np.argmax(logits, axis=-1)
    p, r, f1, _ = precision_recall_fscore_support(labels, preds, average="binary", zero_division=0)
    acc = (preds == labels).mean()
    return {"precision": p, "recall": r, "f1": f1, "accuracy": acc}


def main():
    os.makedirs(OUT_DIR, exist_ok=True)

    # 1) Load parquet (50k base)
    df = pd.read_parquet(PARQUET_PATH)
    for c in [ID_COL, TEXT_COL, SPLIT_COL, SILVER_LABEL_COL]:
        if c not in df.columns:
            raise ValueError(f"Missing column '{c}' in {PARQUET_PATH}. Found: {list(df.columns)}")

    df[ID_COL] = pd.to_numeric(df[ID_COL], errors="coerce").astype("Int64")

    # 2) Load A3 CSV with human labels
    a3 = pd.read_csv(A3_CSV_PATH)
    if ID_COL not in a3.columns:
        raise ValueError(f"Missing '{ID_COL}' in {A3_CSV_PATH}. Found: {list(a3.columns)}")

    # Auto-detect human label column
    if PREFERRED_A3_HUMAN_COL in a3.columns:
        human_col = PREFERRED_A3_HUMAN_COL
    elif "is_green_human" in a3.columns:
        human_col = "is_green_human"
    else:
        raise ValueError(
            f"Could not find a human label column. Expected '{PREFERRED_A3_HUMAN_COL}' or 'is_green_human'. "
            f"Found columns: {list(a3.columns)}"
        )

    a3[ID_COL] = pd.to_numeric(a3[ID_COL], errors="coerce").astype("Int64")
    a3[human_col] = a3[human_col].apply(clean_binary_label)

    a3_labeled = a3.dropna(subset=[ID_COL, human_col]).copy()
    a3_labeled[human_col] = a3_labeled[human_col].astype(int)

    if len(a3_labeled) == 0:
        raise RuntimeError(
            f"No human labels found in '{human_col}' inside {A3_CSV_PATH}. "
            "Make sure you've filled 0/1 and saved the file."
        )

    if len(a3_labeled) != 100:
        print(f"WARNING: expected 100 A3 labeled rows, found {len(a3_labeled)} (continuing anyway)")

    gold_map = dict(zip(a3_labeled[ID_COL].tolist(), a3_labeled[human_col].tolist()))
    print("A3 labeled doc_ids:", len(gold_map))

    # 3) Create is_green_gold_a3 (silver overridden by human for the 100)
    df["is_green_gold_a3"] = df[SILVER_LABEL_COL].astype(int)
    mask = df[ID_COL].isin(gold_map.keys())
    df.loc[mask, "is_green_gold_a3"] = df.loc[mask, ID_COL].map(gold_map).astype(int)

    # 4) Build train/eval sets
    train_silver_df = df[df[SPLIT_COL] == "train_silver"].copy()
    gold_100_df = df[df[ID_COL].isin(gold_map.keys())].copy()

    train_df = pd.concat([train_silver_df, gold_100_df], ignore_index=True)
    train_df["label"] = train_df["is_green_gold_a3"].astype(int)

    eval_silver_df = df[df[SPLIT_COL] == "eval_silver"].copy()
    eval_silver_df["label"] = eval_silver_df[SILVER_LABEL_COL].astype(int)

    gold_eval_df = gold_100_df.copy()
    gold_eval_df["label"] = gold_eval_df["is_green_gold_a3"].astype(int)

    print("\nSizes:")
    print("train_silver:", len(train_silver_df))
    print("gold_100_a3:", len(gold_100_df))
    print("train_final:", len(train_df))
    print("eval_silver:", len(eval_silver_df))

    # 5) HF datasets
    train_ds = Dataset.from_pandas(train_df[[TEXT_COL, "label"]], preserve_index=False)
    eval_ds = Dataset.from_pandas(eval_silver_df[[TEXT_COL, "label"]], preserve_index=False)
    gold_ds = Dataset.from_pandas(gold_eval_df[[TEXT_COL, "label"]], preserve_index=False)

    # 6) Tokenize
    tokenizer = AutoTokenizer.from_pretrained(BASE_MODEL)

    def tok(batch):
        return tokenizer(batch[TEXT_COL], truncation=True, max_length=MAX_LEN)

    train_ds = train_ds.map(tok, batched=True, remove_columns=[TEXT_COL])
    eval_ds = eval_ds.map(tok, batched=True, remove_columns=[TEXT_COL])
    gold_ds = gold_ds.map(tok, batched=True, remove_columns=[TEXT_COL])

    collator = DataCollatorWithPadding(tokenizer=tokenizer)

    # 7) Model
    model = AutoModelForSequenceClassification.from_pretrained(BASE_MODEL, num_labels=2).to(DEVICE)

    # 8) TrainingArguments (old-transformers compatible)
    args = TrainingArguments(
        output_dir=OUT_DIR,
        num_train_epochs=EPOCHS,
        learning_rate=LR,
        per_device_train_batch_size=TRAIN_BS,
        per_device_eval_batch_size=EVAL_BS,
        seed=SEED,
        report_to="none",
        fp16=False,
        logging_steps=50,
        save_steps=500,
    )

    trainer = Trainer(
        model=model,
        args=args,
        train_dataset=train_ds,
        eval_dataset=eval_ds,
        data_collator=collator,
        compute_metrics=compute_metrics,
    )

    # 9) Train once
    trainer.train()

    # 10) Evaluate
    print("\n=== Assignment 3 Model: eval_silver (silver labels) ===")
    m_eval = trainer.evaluate(eval_dataset=eval_ds)
    print(m_eval)

    print("\n=== Assignment 3 Model: gold_100 (A3 human labels) ===")
    m_gold = trainer.evaluate(eval_dataset=gold_ds)
    print(m_gold)

    # 11) Save model + tokenizer
    trainer.save_model(OUT_DIR)
    tokenizer.save_pretrained(OUT_DIR)

    # 12) Save merged parquet
    df.to_parquet(MERGED_OUT, index=False)
    print(f"\nSaved merged dataset: {MERGED_OUT}")
    print(f"Saved fine-tuned model: {OUT_DIR}")


if __name__ == "__main__":
    main()
# Out:
# Using device: mps
# A3 labeled doc_ids: 100
#
# Sizes:
# train_silver: 35000
# gold_100_a3: 100
# train_final: 35100
# eval_silver: 5000
# Map:   0%|          | 0/35100 [00:00<?, ? examples/s]
# Map:   0%|          | 0/5000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/100 [00:00<?, ? examples/s]
# Loading weights:   0%|          | 0/197 [00:00<?, ?it/s]
# MPNetForSequenceClassification LOAD REPORT from: AI-Growth-Lab/PatentSBERTa
# Key                        | Status     |
# ---------------------------+------------+-
# embeddings.position_ids    | UNEXPECTED |
# pooler.dense.weight        | UNEXPECTED |
# pooler.dense.bias          | UNEXPECTED |
# classifier.dense.weight    | MISSING    |
# classifier.out_proj.weight | MISSING    |
# classifier.dense.bias      | MISSING    |
# classifier.out_proj.bias   | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# /opt/miniconda3/envs/venv/lib/python3.13/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <div>
#
#       <progress value='2194' max='2194' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2194/2194 1:07:01, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>0.649193</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.529600</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.504056</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.513348</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.474745</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.494384</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.445602</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.440339</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.470936</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.460302</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>0.464412</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.468069</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>0.459267</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.428980</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>0.432785</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.456675</td>
#     </tr>
#     <tr>
#       <td>850</td>
#       <td>0.455792</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.445401</td>
#     </tr>
#     <tr>
#       <td>950</td>
#       <td>0.488721</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.447255</td>
#     </tr>
#     <tr>
#       <td>1050</td>
#       <td>0.439248</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.427901</td>
#     </tr>
#     <tr>
#       <td>1150</td>
#       <td>0.430855</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.392797</td>
#     </tr>
#     <tr>
#       <td>1250</td>
#       <td>0.439503</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>0.437771</td>
#     </tr>
#     <tr>
#       <td>1350</td>
#       <td>0.425291</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.424669</td>
#     </tr>
#     <tr>
#       <td>1450</td>
#       <td>0.433834</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.447276</td>
#     </tr>
#     <tr>
#       <td>1550</td>
#       <td>0.428013</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.410581</td>
#     </tr>
#     <tr>
#       <td>1650</td>
#       <td>0.409101</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>0.426613</td>
#     </tr>
#     <tr>
#       <td>1750</td>
#       <td>0.434827</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.423740</td>
#     </tr>
#     <tr>
#       <td>1850</td>
#       <td>0.413996</td>
#     </tr>
#     <tr>
#       <td>1900</td>
#       <td>0.386089</td>
#     </tr>
#     <tr>
#       <td>1950</td>
#       <td>0.424252</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.420702</td>
#     </tr>
#     <tr>
#       <td>2050</td>
#       <td>0.411696</td>
#     </tr>
#     <tr>
#       <td>2100</td>
#       <td>0.406396</td>
#     </tr>
#     <tr>
#       <td>2150</td>
#       <td>0.434467</td>
#     </tr>
#   </tbody>
# </table><p>
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# === Assignment 3 Model: eval_silver (silver labels) ===
# /opt/miniconda3/envs/venv/lib/python3.13/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <div>
#
#       <progress value='161' max='157' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [157/157 03:00]
#     </div>
# {'eval_loss': 0.4130362272262573, 'eval_precision': 0.8235048097030531, 'eval_recall': 0.7876, 'eval_f1': 0.8051523205888367, 'eval_accuracy': 0.8094, 'eval_runtime': 177.9072, 'eval_samples_per_second': 28.105, 'eval_steps_per_second': 0.882, 'epoch': 1.0}
#
# === Assignment 3 Model: gold_100 (A3 human labels) ===
# /opt/miniconda3/envs/venv/lib/python3.13/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# {'eval_loss': 0.6464775800704956, 'eval_precision': 0.6666666666666666, 'eval_recall': 0.6296296296296297, 'eval_f1': 0.6476190476190476, 'eval_accuracy': 0.63, 'eval_runtime': 3.5431, 'eval_samples_per_second': 28.224, 'eval_steps_per_second': 1.129, 'epoch': 1.0}
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved merged dataset: patents_50k_green_with_gold_a3.parquet
# Saved fine-tuned model: models_finetuned_patentsberta_green_a3

# %% [markdown]
# # Part E

# %%
import re
import numpy as np
import pandas as pd
import torch

from datasets import Dataset
from transformers import AutoTokenizer, AutoModelForSequenceClassification, Trainer, DataCollatorWithPadding
from sklearn.metrics import precision_recall_fscore_support

# ---------- INPUTS (ret hvis dine navne er anderledes) ----------
PARQUET_A2 = "patents_50k_green_with_gold.parquet"        # fra Assignment 2
PARQUET_A3 = "patents_50k_green_with_gold_a3.parquet"     # fra Assignment 3 (hvis du har gemt en sådan)
MODEL_A3_DIR = "models_finetuned_patentsberta_green_a3"   # din A3 fine-tunede model-mappe

A2_CSV = "hitl_green_100_labeled.csv"   # har llm_green_suggested + is_green_human
A3_CSV = "hitl_green_100_a3-hitl.csv"        # har agent_judge_suggested + is_green_human_a3 (eller tilsvarende)

# Baseline + A2 F1 (du har dem allerede)
BASELINE_F1 = 0.7618
A2_F1 = 0.8033

# Kolonnenavne (ret hvis dine hedder noget andet)
A2_AI_COL = "llm_green_suggested"
A2_HUMAN_COL = "is_green_human"

A3_AI_COL = "agent_judge_suggested"
A3_HUMAN_COL = "is_green_human_a3"

# eval labels for eval_silver
EVAL_SPLIT_COL = "split"
EVAL_SPLIT_NAME = "eval_silver"
EVAL_LABEL_COL = "is_green_silver"

TEXT_COL = "text"
MAX_LEN = 256


# ---------- helpers ----------
def clean_binary_label(x):
    if x is None or (isinstance(x, float) and np.isnan(x)):
        return None
    s = str(x).strip()
    if s == "":
        return None
    if re.fullmatch(r"[01](\.0+)?", s):
        return int(float(s))
    return None

def agreement(csv_path: str, ai_col: str, human_col: str):
    df = pd.read_csv(csv_path)
    if ai_col not in df.columns or human_col not in df.columns:
        return None, 0

    df[ai_col] = df[ai_col].apply(clean_binary_label)
    df[human_col] = df[human_col].apply(clean_binary_label)
    df = df.dropna(subset=[ai_col, human_col])
    if len(df) == 0:
        return None, 0
    rate = (df[ai_col].astype(int) == df[human_col].astype(int)).mean()
    return float(rate), int(len(df))

def eval_f1_model(model_dir: str, parquet_path: str):
    df = pd.read_parquet(parquet_path)
    eval_df = df[df[EVAL_SPLIT_COL] == EVAL_SPLIT_NAME].copy()
    eval_df["label"] = eval_df[EVAL_LABEL_COL].astype(int)

    ds = Dataset.from_pandas(eval_df[[TEXT_COL, "label"]], preserve_index=False)

    tokenizer = AutoTokenizer.from_pretrained(model_dir)
    def tok(batch):
        return tokenizer(batch[TEXT_COL], truncation=True, max_length=MAX_LEN)
    ds = ds.map(tok, batched=True, remove_columns=[TEXT_COL])

    collator = DataCollatorWithPadding(tokenizer=tokenizer, return_tensors="pt")

    model = AutoModelForSequenceClassification.from_pretrained(model_dir)

    # Device
    if torch.backends.mps.is_available():
        device = "mps"
    elif torch.cuda.is_available():
        device = "cuda"
    else:
        device = "cpu"
    model.to(device)

    trainer = Trainer(model=model, data_collator=collator)
    pred = trainer.predict(ds)

    logits = pred.predictions
    labels = pred.label_ids
    preds = np.argmax(logits, axis=1)

    p, r, f1, _ = precision_recall_fscore_support(labels, preds, average="binary", zero_division=0)
    acc = (preds == labels).mean()
    return float(f1), float(p), float(r), float(acc)


def main():
    # Agreement % for A2 and A3
    a2_agree, a2_n = agreement(A2_CSV, A2_AI_COL, A2_HUMAN_COL)
    a3_agree, a3_n = agreement(A3_CSV, A3_AI_COL, A3_HUMAN_COL)

    # A3 F1 on eval_silver
    a3_f1, a3_p, a3_r, a3_acc = eval_f1_model(MODEL_A3_DIR, PARQUET_A3)

    print("\n=== Agreement (AI suggestion vs Human) ===")
    if a2_agree is None:
        print("Assignment 2 agreement: could not compute (missing columns or labels)")
    else:
        print(f"Assignment 2 (Simple LLM): {a2_agree*100:.1f}%  (n={a2_n})")

    if a3_agree is None:
        print("Assignment 3 agreement: could not compute (missing columns or labels)")
    else:
        print(f"Assignment 3 (Agents/QLoRA): {a3_agree*100:.1f}%  (n={a3_n})")

    print("\n=== Assignment 3 Model on eval_silver ===")
    print(f"Precision: {a3_p:.4f}")
    print(f"Recall:    {a3_r:.4f}")
    print(f"F1:        {a3_f1:.4f}")
    print(f"Accuracy:  {a3_acc:.4f}")

    print("\n=== README table (copy-paste) ===")
    print("| Model Version | Training Data Source | F1 Score (Eval Set) |")
    print("|---|---|---:|")
    print(f"| 1. Baseline | Frozen Embeddings (No Fine-tuning) | {BASELINE_F1:.4f} |")
    print(f"| 2. Assignment 2 Model | Fine-tuned on Silver + Gold (Simple LLM) | {A2_F1:.4f} |")
    print(f"| 3. Assignment 3 Model | Fine-tuned on Silver + Gold (Agents/QLoRA) | {a3_f1:.4f} |")

    print("\n=== Suggested 2–3 sentence reflection template ===")
    if a3_f1 > A2_F1 + 0.005:
        verdict = "improved"
    elif a3_f1 < A2_F1 - 0.005:
        verdict = "did not improve"
    else:
        verdict = "was similar"

    print(
        f"Compared to Assignment 2, the advanced workflow {verdict} downstream model performance on the eval set "
        f"(F1: {A2_F1:.4f} → {a3_f1:.4f}). "
        "This suggests that structured labeling can (or cannot) add value beyond a simple LLM approach, "
        "depending on how much the advanced method improves label quality on borderline cases."
    )

    print("\n(You can also include the agreement comparison above in README.)")


if __name__ == "__main__":
    main()
# Out:
# Map:   0%|          | 0/5000 [00:00<?, ? examples/s]
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# /opt/miniconda3/envs/venv/lib/python3.13/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# === Agreement (AI suggestion vs Human) ===
# Assignment 2 (Simple LLM): 91.0%  (n=100)
# Assignment 3 (Agents/QLoRA): 95.0%  (n=100)
#
# === Assignment 3 Model on eval_silver ===
# Precision: 0.8235
# Recall:    0.7876
# F1:        0.8052
# Accuracy:  0.8094
#
# === README table (copy-paste) ===
# | Model Version | Training Data Source | F1 Score (Eval Set) |
# |---|---|---:|
# | 1. Baseline | Frozen Embeddings (No Fine-tuning) | 0.7618 |
# | 2. Assignment 2 Model | Fine-tuned on Silver + Gold (Simple LLM) | 0.8033 |
# | 3. Assignment 3 Model | Fine-tuned on Silver + Gold (Agents/QLoRA) | 0.8052 |
#
# === Suggested 2–3 sentence reflection template ===
# Compared to Assignment 2, the advanced workflow was similar downstream model performance on the eval set (F1: 0.8033 → 0.8052). This suggests that structured labeling can (or cannot) add value beyond a simple LLM approach, depending on how much the advanced method improves label quality on borderline cases.
#
# (You can also include the agreement comparison above in README.)
